# %% [markdown]
# # Which clock explains the reported increase?
#
# Compare the full settled population with recognition-period accounting. Recent fixed-window truth is available only inside the generator.

# %%
import json
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
cfg = json.loads((ROOT / "configs/base.json").read_text())

# %%
from fraud_case import cohorts, data

history = data.history(cfg["n_history"], cfg["seed"])
cohort_results = cohorts.run(history, ROOT)
cohort_results.tail(10)
