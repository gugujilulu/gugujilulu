# %% [markdown]
# # Which improvement comes from additional information?
#
# The same-information comparison, PSP addition and specialization answer different questions. Calibration and ranking are reported together.

# %%
from pathlib import Path
import sys, json
ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
cfg = json.loads((ROOT / 'configs/base.json').read_text())

# %%
from fraud_case import models
model_results, calibration = models.run(cfg["n_model"], cfg["seed"])
model_results
