# %% [markdown]
# # Does the merchant comparison survive adjustment?
#
# A and B encode different mechanisms. The output measures fraud incidence, while the supplied matched case uses loss rates.

# %%
from pathlib import Path
import sys, json
ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
cfg = json.loads((ROOT / 'configs/base.json').read_text())

# %%
from fraud_case import data, cohorts
history = data.history(cfg["n_history"], cfg["seed"])
cohorts.merchant_comparison(history)
