# %% [markdown]
# # What changes across all assigned attempts?
#
# Interpret net loss per attempted value and completion per attempt together. Potential outcomes are reserved for estimator validation.

# %%
from pathlib import Path
import sys, json
ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
cfg = json.loads((ROOT / 'configs/base.json').read_text())

# %%
from fraud_case import data, estimators
trial = data.experiment(cfg["n_transactions"], cfg["seed"])
observed = trial.drop(columns=[f"{m}{z}" for m in ["net", "gross", "completion"] for z in [0, 1]])
estimators.analyze(observed)
